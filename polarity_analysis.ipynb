# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# Load and preprocess data
df = pd.read_csv("final.csv")
#df = df.dropna().reset_index(drop=True)
df
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0           author/location  \
# 0                 0             0        1584               Pune, India
# 1                 1             1        1447                    India
# 2                 2             2        1446                     India
# 3                 3             3        9731  भारत।हिंदुस्तान।India 🇮🇳
# 4                 4             4        1445          New Delhi, India
# ...             ...           ...         ...                       ...
# 11559         11559         11559         546          Lahore, Pakistan
# 11560         11560         11560        8842          New Delhi, India
# 11561         11561         11561        8948         Chandigarh, India
# 11562         11562         11562        8884                     India
# 11563         11563         11563        8700            United Kingdom
#
#                             createdAt                   id  \
# 0      Sat Apr 11 18:45:11 +0000 2020  1249045851306987520
# 1      Fri Apr 03 07:53:41 +0000 2020  1245982793072439296
# 2      Fri Apr 03 07:07:21 +0000 2020  1245971132022317058
# 3      Sat Apr 30 14:42:09 +0000 2022  1520413198985224193
# 4      Fri Apr 03 08:00:17 +0000 2020  1245984452607688704
# ...                               ...                  ...
# 11559  Thu Jan 27 13:20:19 +0000 2022  1214642451606052865
# 11560  Sun Jan 02 17:43:54 +0000 2022  1477697170375540736
# 11561  Wed Jan 19 11:30:20 +0000 2022  1483763753447747585
# 11562  Sat Jan 01 04:43:30 +0000 2022  1477138390826897412
# 11563  Wed Jan 26 21:05:01 +0000 2022  1486445093271789568
#
#                                                     text         Country  \
# 0      hello bookmyshow  the fact that you let ur pla...           India
# 1      1  march 15  hindu mahasabha organized a gau m...           India
# 2      the media  intellectuals  amp  celebrities who...           India
# 3      whatever is happening in punjab \n is directly...           India
# 4      methods of disinformation — the nyt’s attempts...           India
# ...                                                  ...             ...
# 11559   pakistan has declared over 1 000 years old  h...           India
# 11560  notwithstanding the omicron outbreak and the r...           India
# 11561         i need sudarshan tv       \n\n hinduphobia           India
# 11562    assumption much  bollywood s hinduphobia is ...           India
# 11563  good question  why don’t   amp   care about hi...  United Kingdom
#
#       Month_Year  hate  ... Optimistic  Thankful  Empathetic  Pessimistic  \
# 0       Apr-2020     0  ...      False     False       False        False
# 1       Apr-2020     0  ...      False     False       False        False
# 2       Apr-2020     0  ...      False     False       False        False
# 3       Apr-2020     0  ...      False     False       False        False
# 4       Apr-2020     0  ...      False     False       False        False
# ...          ...   ...  ...        ...       ...         ...          ...
# 11559   Jan-2022     0  ...      False     False       False        False
# 11560   Jan-2022     0  ...      False     False       False        False
# 11561   Jan-2022     0  ...      False     False       False        False
# 11562   Jan-2022     0  ...      False     False       False        False
# 11563   Jan-2022     0  ...      False     False       False        False
#
#        Anxious    Sad  Annoyed  Denial  Official report  Joking
# 0        False  False     True   False            False   False
# 1        False  False    False   False             True   False
# 2        False  False     True   False            False   False
# 3        False  False     True   False            False   False
# 4        False  False     True   False            False   False
# ...        ...    ...      ...     ...              ...     ...
# 11559    False  False    False   False            False   False
# 11560    False  False    False   False             True   False
# 11561    False  False     True   False            False    True
# 11562    False  False     True   False            False   False
# 11563    False  False     True   False            False   False
#
# [11564 rows x 21 columns]

# %%
df['createdAt'] = pd.to_datetime(df['createdAt'])
df
# Out:
# /tmp/ipykernel_742047/1889183615.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['createdAt'] = pd.to_datetime(df['createdAt'])
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0           author/location  \
# 0                 0             0        1584               Pune, India
# 1                 1             1        1447                    India
# 2                 2             2        1446                     India
# 3                 3             3        9731  भारत।हिंदुस्तान।India 🇮🇳
# 4                 4             4        1445          New Delhi, India
# ...             ...           ...         ...                       ...
# 11559         11559         11559         546          Lahore, Pakistan
# 11560         11560         11560        8842          New Delhi, India
# 11561         11561         11561        8948         Chandigarh, India
# 11562         11562         11562        8884                     India
# 11563         11563         11563        8700            United Kingdom
#
#                       createdAt                   id  \
# 0     2020-04-11 18:45:11+00:00  1249045851306987520
# 1     2020-04-03 07:53:41+00:00  1245982793072439296
# 2     2020-04-03 07:07:21+00:00  1245971132022317058
# 3     2022-04-30 14:42:09+00:00  1520413198985224193
# 4     2020-04-03 08:00:17+00:00  1245984452607688704
# ...                         ...                  ...
# 11559 2022-01-27 13:20:19+00:00  1214642451606052865
# 11560 2022-01-02 17:43:54+00:00  1477697170375540736
# 11561 2022-01-19 11:30:20+00:00  1483763753447747585
# 11562 2022-01-01 04:43:30+00:00  1477138390826897412
# 11563 2022-01-26 21:05:01+00:00  1486445093271789568
#
#                                                     text         Country  \
# 0      hello bookmyshow  the fact that you let ur pla...           India
# 1      1  march 15  hindu mahasabha organized a gau m...           India
# 2      the media  intellectuals  amp  celebrities who...           India
# 3      whatever is happening in punjab \n is directly...           India
# 4      methods of disinformation — the nyt’s attempts...           India
# ...                                                  ...             ...
# 11559   pakistan has declared over 1 000 years old  h...           India
# 11560  notwithstanding the omicron outbreak and the r...           India
# 11561         i need sudarshan tv       \n\n hinduphobia           India
# 11562    assumption much  bollywood s hinduphobia is ...           India
# 11563  good question  why don’t   amp   care about hi...  United Kingdom
#
#       Month_Year  hate  ... Optimistic  Thankful  Empathetic  Pessimistic  \
# 0       Apr-2020     0  ...      False     False       False        False
# 1       Apr-2020     0  ...      False     False       False        False
# 2       Apr-2020     0  ...      False     False       False        False
# 3       Apr-2020     0  ...      False     False       False        False
# 4       Apr-2020     0  ...      False     False       False        False
# ...          ...   ...  ...        ...       ...         ...          ...
# 11559   Jan-2022     0  ...      False     False       False        False
# 11560   Jan-2022     0  ...      False     False       False        False
# 11561   Jan-2022     0  ...      False     False       False        False
# 11562   Jan-2022     0  ...      False     False       False        False
# 11563   Jan-2022     0  ...      False     False       False        False
#
#        Anxious    Sad  Annoyed  Denial  Official report  Joking
# 0        False  False     True   False            False   False
# 1        False  False    False   False             True   False
# 2        False  False     True   False            False   False
# 3        False  False     True   False            False   False
# 4        False  False     True   False            False   False
# ...        ...    ...      ...     ...              ...     ...
# 11559    False  False    False   False            False   False
# 11560    False  False    False   False             True   False
# 11561    False  False     True   False            False    True
# 11562    False  False     True   False            False   False
# 11563    False  False     True   False            False   False
#
# [11564 rows x 21 columns]

# %% [markdown]
# ## Polarity Score Calculation using TextBlob

# %%
from textblob import TextBlob
#Create a function to get the polarity
def getPolarity(text):
   return TextBlob(text).sentiment.polarity

df['TextBlob_Polarity'] = df['text'].apply(getPolarity)

# %%
# !pip install textblob
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting textblob
#   Downloading textblob-0.18.0.post0-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: nltk>=3.8 in /home/iiitnr/.local/lib/python3.10/site-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in /home/iiitnr/.local/lib/python3.10/site-packages (from nltk>=3.8->textblob) (8.1.7)
# Requirement already satisfied: joblib in /home/iiitnr/.local/lib/python3.10/site-packages (from nltk>=3.8->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/iiitnr/.local/lib/python3.10/site-packages (from nltk>=3.8->textblob) (2024.5.15)
# Requirement already satisfied: tqdm in /home/iiitnr/.local/lib/python3.10/site-packages (from nltk>=3.8->textblob) (4.66.5)
# Downloading textblob-0.18.0.post0-py3-none-any.whl (626 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 626.3/626.3 kB 7.8 MB/s eta 0:00:00
# Installing collected packages: textblob
# Successfully installed textblob-0.18.0.post0
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
plt.figure(figsize=(15, 11))
sns.distplot(df['TextBlob_Polarity'],bins=20, hist=True, color='midnightblue', hist_kws={'alpha':0.5, 'edgecolor':'black'})
plt.yticks(fontsize= 25)
plt.xticks(fontsize = 25)
plt.ylabel('Density', fontsize=25)
plt.xlabel('TextBlob Polarity', fontsize=25)
# Out:
# /tmp/ipykernel_742047/94256160.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['TextBlob_Polarity'],bins=20, hist=True, color='midnightblue', hist_kws={'alpha':0.5, 'edgecolor':'black'})
# Text(0.5, 0, 'TextBlob Polarity')

# %% [markdown]
# ## Polarity Score Calculation using Custom Sentiment Labels and Weights

# %%
# Define sentiment polarity and weight ratios
sentiment_polarity = {
    'Optimistic': 2,
    'Thankful': 3,
    'Joking': 1,
    'Pessimistic': -4,
    'Anxious': -2,
    'Sad': -3,
    'Annoyed': -1,
    'Denial': -5,
    'Empathetic': 0,
    'Official report': 0
}

labels = list(sentiment_polarity.keys())
weight_ratios = {
    'Optimistic': 3,
    'Thankful': 2,
    'Empathetic': 0,
    'Pessimistic': -3,
    'Anxious': -2,
    'Sad': -2,
    'Annoyed': -1,
    'Denial': -4,
    'Official report': 0,
    'Joking': 1
}

# %%
# Function to calculate polarity scores
def calculate_polarity_scores(df, weight_ratios):
    # Apply weight ratios to sentiment labels
    weighted_df = df[labels].apply(lambda x: x * weight_ratios[x.name])
    # Sum up the weighted scores for each row
    df['polarity_score'] = weighted_df.sum(axis=1) / len(labels)
    return df

# Calculate polarity scores for the entire DataFrame
df = calculate_polarity_scores(df, weight_ratios)

df
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0           author/location  \
# 0                 0             0        1584               Pune, India
# 1                 1             1        1447                    India
# 2                 2             2        1446                     India
# 3                 3             3        9731  भारत।हिंदुस्तान।India 🇮🇳
# 4                 4             4        1445          New Delhi, India
# ...             ...           ...         ...                       ...
# 11559         11559         11559         546          Lahore, Pakistan
# 11560         11560         11560        8842          New Delhi, India
# 11561         11561         11561        8948         Chandigarh, India
# 11562         11562         11562        8884                     India
# 11563         11563         11563        8700            United Kingdom
#
#                       createdAt                   id  \
# 0     2020-04-11 18:45:11+00:00  1249045851306987520
# 1     2020-04-03 07:53:41+00:00  1245982793072439296
# 2     2020-04-03 07:07:21+00:00  1245971132022317058
# 3     2022-04-30 14:42:09+00:00  1520413198985224193
# 4     2020-04-03 08:00:17+00:00  1245984452607688704
# ...                         ...                  ...
# 11559 2022-01-27 13:20:19+00:00  1214642451606052865
# 11560 2022-01-02 17:43:54+00:00  1477697170375540736
# 11561 2022-01-19 11:30:20+00:00  1483763753447747585
# 11562 2022-01-01 04:43:30+00:00  1477138390826897412
# 11563 2022-01-26 21:05:01+00:00  1486445093271789568
#
#                                                     text         Country  \
# 0      hello bookmyshow  the fact that you let ur pla...           India
# 1      1  march 15  hindu mahasabha organized a gau m...           India
# 2      the media  intellectuals  amp  celebrities who...           India
# 3      whatever is happening in punjab \n is directly...           India
# 4      methods of disinformation — the nyt’s attempts...           India
# ...                                                  ...             ...
# 11559   pakistan has declared over 1 000 years old  h...           India
# 11560  notwithstanding the omicron outbreak and the r...           India
# 11561         i need sudarshan tv       \n\n hinduphobia           India
# 11562    assumption much  bollywood s hinduphobia is ...           India
# 11563  good question  why don’t   amp   care about hi...  United Kingdom
#
#       Month_Year  hate  ... Empathetic  Pessimistic  Anxious    Sad  Annoyed  \
# 0       Apr-2020     0  ...      False        False    False  False     True
# 1       Apr-2020     0  ...      False        False    False  False    False
# 2       Apr-2020     0  ...      False        False    False  False     True
# 3       Apr-2020     0  ...      False        False    False  False     True
# 4       Apr-2020     0  ...      False        False    False  False     True
# ...          ...   ...  ...        ...          ...      ...    ...      ...
# 11559   Jan-2022     0  ...      False        False    False  False    False
# 11560   Jan-2022     0  ...      False        False    False  False    False
# 11561   Jan-2022     0  ...      False        False    False  False     True
# 11562   Jan-2022     0  ...      False        False    False  False     True
# 11563   Jan-2022     0  ...      False        False    False  False     True
#
#        Denial  Official report  Joking  TextBlob_Polarity  polarity_score
# 0       False            False   False           0.000000            -0.1
# 1       False             True   False           0.026984             0.0
# 2       False            False   False          -0.216667            -0.1
# 3       False            False   False           0.225000            -0.1
# 4       False            False   False           0.000000            -0.1
# ...       ...              ...     ...                ...             ...
# 11559   False            False   False          -0.006250             0.0
# 11560   False             True   False           0.400000             0.0
# 11561   False            False    True           0.000000             0.0
# 11562   False            False   False           0.100000            -0.1
# 11563   False            False   False           0.700000            -0.1
#
# [11564 rows x 23 columns]

# %%
df.to_csv("WithPolarity.csv")

# %%
import numpy as np
polarity_scores = df['polarity_score']
unique_scores = sorted(polarity_scores.unique())
my_bins = [x - 0.25 for x in unique_scores] + [unique_scores[-1] + 0.25]

plt.figure(figsize=(15, 11))
sns.distplot(polarity_scores, bins=my_bins, kde=True, color='midnightblue', hist_kws={'alpha':0.5, 'edgecolor':'black'})
plt.yticks(fontsize=25)
plt.xticks(fontsize=25)
plt.ylabel('Density', fontsize=25)
plt.xlabel('Customed Polarity', fontsize=25)
plt.show()
# Out:
# /tmp/ipykernel_742047/209141763.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(polarity_scores, bins=my_bins, kde=True, color='midnightblue', hist_kws={'alpha':0.5, 'edgecolor':'black'})

# %% [markdown]
# ### Violin Plot

# %%
plt.figure(figsize=(12,8))
sns.violinplot(data=df,x='Country',y='polarity_score')
plt.yticks(fontsize= 25)
plt.xticks(fontsize = 25)
plt.ylabel('Polarity Score', fontsize = 25)
plt.xlabel('Country', fontsize = 25)
# Out:
# Text(0.5, 0, 'Country')

# %% [markdown]
# ### Variation of Mean of Customed polarity score over months

# %%
# Group the DataFrame by month, country, and sentiment and calculate the mean polarity score for each group
grouped = df.groupby(['Month_Year', 'Country'])['polarity_score'].mean().reset_index()

# Rename the columns
grouped.columns = ['Month', 'Country', 'Mean of Customed Polarity']
     

plt.figure(figsize=(12,5))
sns.set(style="darkgrid")
sns.lineplot(x="Month", y="Mean of Customed Polarity", hue="Country", data=grouped)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Variation of Mean of TextBlob polarity score over months

# %%
TB_pol = df.groupby(['Month_Year', 'Country'])['TextBlob_Polarity'].mean().reset_index()

# Rename the columns
TB_pol.columns = ['Month', 'Country', 'Mean of TextBlob Polarity']
     

plt.figure(figsize=(12,5))
sns.set(style="darkgrid")
sns.lineplot(x="Month", y="Mean of TextBlob Polarity", hue="Country", data=TB_pol)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Heatmap

# %%
# Define the date ranges
start_date1 = '2020-04-01'
end_date1 = '2021-01-01'
start_date2 = '2021-01-01'
end_date2 = '2022-01-31'

# Split the dataframe based on the date ranges
df1 = df[(df['createdAt'] >= start_date1) & (df['createdAt'] < end_date1)]
df2 = df[(df['createdAt'] >= start_date2) & (df['createdAt'] < end_date2)]

# %%
df.columns
# Out:
# Index(['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0', 'author/location',
#        'createdAt', 'id', 'text', 'Country', 'Month_Year', 'hate', 'Time',
#        'Optimistic', 'Thankful', 'Empathetic', 'Pessimistic', 'Anxious', 'Sad',
#        'Annoyed', 'Denial', 'Official report', 'Joking', 'TextBlob_Polarity',
#        'polarity_score'],
#       dtype='object')

# %%
import numpy as np
emotions = list(df.columns[11:21])
emotions.remove('Official report')
only_emotes = df2[emotions]
only_emotes
# Out:
#        Optimistic  Thankful  Empathetic  Pessimistic  Anxious    Sad  Annoyed  \
# 5558        False     False       False        False    False  False     True
# 5560         True     False       False        False    False  False    False
# 5561        False     False       False        False    False  False     True
# 5563        False     False       False        False    False  False     True
# 5570        False     False       False        False    False  False     True
# ...           ...       ...         ...          ...      ...    ...      ...
# 11559       False     False       False        False    False  False    False
# 11560       False     False       False        False    False  False    False
# 11561       False     False       False        False    False  False     True
# 11562       False     False       False        False    False  False     True
# 11563       False     False       False        False    False  False     True
#
#        Denial  Joking
# 5558    False   False
# 5560    False    True
# 5561    False   False
# 5563    False   False
# 5570    False   False
# ...       ...     ...
# 11559   False   False
# 11560   False   False
# 11561   False    True
# 11562   False   False
# 11563   False   False
#
# [4439 rows x 9 columns]

# %%
emote_array = np.zeros((9, 9))
e2i = {
    'Optimistic' : 0, 'Thankful' : 1, 'Empathetic' : 2, 'Pessimistic' : 3, 'Anxious' : 4, 'Sad' : 5, 'Annoyed' : 6, 'Denial' : 7, 
    'Joking' : 8
}
for i in range(len(only_emotes)):
    l = only_emotes.iloc[i].tolist()
    for j in range(9):
        if l[j] == 1:
            emote_array[j][j] += 1
        for k in range(j+1, 9):
            if (l[j] == 1) and (l[k] == 1):
                emote_array[j][k] += int(1)
                emote_array[k][j] += int(1)

emote_df = pd.DataFrame(emote_array, columns = emotions)
for col in emote_df:
    emote_df[col] = emote_df[col].astype(int)
     

fig = plt.figure(figsize = (16, 13))
sns.set(font_scale = 2)
sns.heatmap(emote_df, annot = True, cmap = 'coolwarm', xticklabels = emote_df.columns, yticklabels = emote_df.columns,
            fmt = 'g', annot_kws = {"size" : 16})
# Out:
# <AxesSubplot:>
